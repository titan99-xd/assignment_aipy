# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Ensure plots display in Colab
# %matplotlib inline

# %%
#always make sure to import the csv file otherwise it wont run (just upload the dataset on tge sample_data folder and you are ready to go)
#Load dataset
data = pd.read_csv('/content/sample_data/weight-height.csv')

#print the dataset if you want
#print(data)

# %%
# Extract height and weight (make sure to see the column name at the top and it matches)
heights_in = data['Height']
weights_lb = data['Weight']

# %%
# Convert to cm and kg
heights_cm = heights_in * 2.54
weights_kg = weights_lb * 0.453592

# %%
# Create histogram
plt.hist(heights_cm, edgecolor='black')
plt.title('Height Distribution')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')

# Show the plot
plt.show()
